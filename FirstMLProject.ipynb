# %% [markdown]
# <a href="https://colab.research.google.com/github/zaranasavani/MyLearning/blob/main/FirstMLProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **My First ML Project**

# %% [markdown]
# ### **Load The Data**

# %%
# prompt:

import pandas as pd

# Load the data from a CSV file
data = pd.read_csv('data.csv')

# Print the first few rows of the data
print(data.head())
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %% [markdown]
# ### **Data Preparation**

# %% [markdown]
# #### Data Separation as X and Y

# %%
y = df['Data.Wind.Speed']
y
# Out:
# 0         4.33
# 1         3.86
# 2         9.73
# 3         6.86
# 4         7.80
#          ...
# 16738    19.98
# 16739    15.16
# 16740     1.65
# 16741    18.16
# 16742     7.51
# Name: Data.Wind.Speed, Length: 16743, dtype: float64

# %%
x = df.drop('Data.Wind.Speed', axis=1)
x['Date.Full'] = pd.to_datetime(x['Date.Full'])
x['Date.Full'] = x['Date.Full'].  astype(int)
x
# Out:
#        Data.Precipitation            Date.Full  Date.Month  Date.Week of  \
# 0                    0.00  1451779200000000000           1             3
# 1                    0.00  1451779200000000000           1             3
# 2                    0.16  1451779200000000000           1             3
# 3                    0.00  1451779200000000000           1             3
# 4                    0.01  1451779200000000000           1             3
# ...                   ...                  ...         ...           ...
# 16738                0.08  1483228800000000000           1             1
# 16739                0.00  1483228800000000000           1             1
# 16740                0.00  1483228800000000000           1             1
# 16741                0.06  1483228800000000000           1             1
# 16742                0.10  1483228800000000000           1             1
#
#        Date.Year Station.City Station.Code Station.Location Station.State  \
# ...

# %% [markdown]
# #### Data Splitting

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)
x_train_encoded = pd.get_dummies(x_train)
x_test_encoded = pd.get_dummies(x_test)
x_train
# Out:
#        Data.Precipitation            Date.Full  Date.Month  Date.Week of  \
# 6879                 0.51  1464480000000000000           5            29
# 5392                 0.59  1462060800000000000           5             1
# 4670                 0.65  1460246400000000000           4            10
# 10587                0.31  1471737600000000000           8            21
# 10069                0.07  1470528000000000000           8             7
# ...                   ...                  ...         ...           ...
# 16304                0.49  1482624000000000000          12            25
# 79                   0.12  1451779200000000000           1             3
# 12119                0.00  1474761600000000000           9            25
# 14147                0.00  1478390400000000000          11             6
# 5640                 0.00  1462060800000000000           5             1
#
#        Date.Year    Station.City Station.Code    Station.Location  \
# ...

# %%
x_test
# Out:
#        Data.Precipitation            Date.Full  Date.Month  Date.Week of  \
# 3046                 0.24  1457222400000000000           3             6
# 6380                 0.34  1463875200000000000           5            22
# 15927                0.73  1482019200000000000          12            18
# 3493                 0.00  1458432000000000000           3            20
# 5147                 0.89  1461456000000000000           4            24
# ...                   ...                  ...         ...           ...
# 11313                1.20  1472947200000000000           9             4
# 12467                0.00  1475366400000000000          10             2
# 8285                 1.08  1467504000000000000           7             3
# 5864                 0.62  1462665600000000000           5             8
# 2078                 0.00  1455408000000000000           2            14
#
#        Date.Year   Station.City Station.Code   Station.Location  \
# ...

# %% [markdown]
# ### **Model Building**

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train_encoded, y_train)
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(x_train_encoded)
y_lr_test_pred = lr.predict(x_test_encoded)

# %%
y_lr_train_pred
# Out:
# array([5.678367  , 7.96251519, 6.23297083, ..., 5.61756425, 5.15086247,
#        7.41407161])

# %%
y_lr_test_pred
# Out:
# array([7.01844687, 5.78813841, 6.3764055 , ..., 6.33062826, 5.0599038 ,
#        5.84650466])

# %% [markdown]
# ### **Evaluate model Performance**

# %%
y_train
# Out:
# 6879      3.92
# 5392      6.70
# 4670      6.84
# 10587     6.05
# 10069     5.68
#          ...
# 16304     6.61
# 79        9.33
# 12119     0.30
# 14147     5.25
# 5640     13.60
# Name: Data.Wind.Speed, Length: 13394, dtype: float64

# %%
y_lr_train_pred
# Out:
# array([5.678367  , 7.96251519, 6.23297083, ..., 5.61756425, 5.15086247,
#        7.41407161])
